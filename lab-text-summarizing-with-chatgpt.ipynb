# %% [markdown]
# # Text summarizing with ChaptGPT
# In this lesson, you will summarize text with a focus on specific topics.
#
# ## Setup

# %%
from openai import OpenAI
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)


def get_completion(prompt, model="gpt-3.5-turbo"): # Andrew mentioned that the prompt/ completion paradigm is preferable for this class
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %% [markdown]
# ## Text to summarize

# %%
prod_review = """
Got this panda plush toy for my daughter's birthday, 
who loves it and takes it everywhere. It's soft and \ 
super cute, and its face has a friendly look. It's \ 
a bit small for what I paid though. I think there \ 
might be other options that are bigger for the \ 
same price. It arrived a day earlier than expected, \ 
so I got to play with it myself before I gave it \ 
to her.
"""
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\ '
# <>:3: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/zt/w93lx4vj4bdbsqvppzkc5_940000gn/T/ipykernel_17281/2462688894.py:3: SyntaxWarning: invalid escape sequence '\ '
#   who loves it and takes it everywhere. It's soft and \

# %% [markdown]
# ## Summarize with a word/sentence/character limit

# %%
prompt = f"""
Your task is to generate a short summary of a product \
review from an ecommerce site. 

Summarize the review below, delimited by triple 
backticks, in at most 30 words. 

Review: ```{prod_review}```
"""

response = get_completion(prompt)
print(response)
# Out:
# Soft, cute panda plush loved by daughter, but small for price. Arrived early, friendly face. Consider larger options for same cost.

# %% [markdown]
# ## Summarize with a focus on shipping and delivery

# %%
prompt = f"""
Your task is to generate a short summary of a product \
review from an ecommerce site to give feedback to the \
Shipping deparmtment. 

Summarize the review below, delimited by triple 
backticks, in at most 30 words, and focusing on any aspects \
that mention shipping and delivery of the product. 

Review: ```{prod_review}```
"""

response = get_completion(prompt)
print(response)
# Out:
# The customer was pleased with the early delivery of the panda plush toy, but felt it was slightly small for the price paid.

# %% [markdown]
# ## Summarize with a focus on price and value

# %%
prompt = f"""
Your task is to generate a short summary of a product \
review from an ecommerce site to give feedback to the \
pricing deparmtment, responsible for determining the \
price of the product.  

Summarize the review below, delimited by triple 
backticks, in at most 30 words, and focusing on any aspects \
that are relevant to the price and perceived value. 

Review: ```{prod_review}```
"""

response = get_completion(prompt)
print(response)
# Out:
# The panda plush toy is loved for its softness and cuteness, but some customers may find it small for the price. Consider offering larger options for the same price.

# %% [markdown]
# #### Comment
# - Summaries include topics that are not related to the topic of focus.

# %% [markdown]
# ## Try "extract" instead of "summarize"

# %%
prompt = f"""
Your task is to extract relevant information from \ 
a product review from an ecommerce site to give \
feedback to the Shipping department. 

From the review below, delimited by triple quotes \
extract the information relevant to shipping and \ 
delivery. Limit to 30 words. 

Review: ```{prod_review}```
"""

response = get_completion(prompt)
print(response)
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\ '
# <>:12: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/zt/w93lx4vj4bdbsqvppzkc5_940000gn/T/ipykernel_17281/2053972773.py:12: SyntaxWarning: invalid escape sequence '\ '
# Feedback: The product arrived a day earlier than expected, which was a pleasant surprise. Consider offering larger options for the same price to improve customer satisfaction.

# %% [markdown]
# ## Summarize multiple product reviews

# %%
review_1 = prod_review 

# review for a standing lamp
review_2 = """
Needed a nice lamp for my bedroom, and this one \
had additional storage and not too high of a price \
point. Got it fast - arrived in 2 days. The string \
to the lamp broke during the transit and the company \
happily sent over a new one. Came within a few days \
as well. It was easy to put together. Then I had a \
missing part, so I contacted their support and they \
very quickly got me the missing piece! Seems to me \
to be a great company that cares about their customers \
and products. 
"""

# review for an electric toothbrush
review_3 = """
My dental hygienist recommended an electric toothbrush, \
which is why I got this. The battery life seems to be \
pretty impressive so far. After initial charging and \
leaving the charger plugged in for the first week to \
condition the battery, I've unplugged the charger and \
been using it for twice daily brushing for the last \
3 weeks all on the same charge. But the toothbrush head \
is too small. I’ve seen baby toothbrushes bigger than \
this one. I wish the head was bigger with different \
length bristles to get between teeth better because \
this one doesn’t.  Overall if you can get this one \
around the $50 mark, it's a good deal. The manufactuer's \
replacements heads are pretty expensive, but you can \
get generic ones that're more reasonably priced. This \
toothbrush makes me feel like I've been to the dentist \
every day. My teeth feel sparkly clean! 
"""

# review for a blender
review_4 = """
So, they still had the 17 piece system on seasonal \
sale for around $49 in the month of November, about \
half off, but for some reason (call it price gouging) \
around the second week of December the prices all went \
up to about anywhere from between $70-$89 for the same \
system. And the 11 piece system went up around $10 or \
so in price also from the earlier sale price of $29. \
So it looks okay, but if you look at the base, the part \
where the blade locks into place doesn’t look as good \
as in previous editions from a few years ago, but I \
plan to be very gentle with it (example, I crush \
very hard items like beans, ice, rice, etc. in the \ 
blender first then pulverize them in the serving size \
I want in the blender then switch to the whipping \
blade for a finer flour, and use the cross cutting blade \
first when making smoothies, then use the flat blade \
if I need them finer/less pulpy). Special tip when making \
smoothies, finely cut and freeze the fruits and \
vegetables (if using spinach-lightly stew soften the \ 
spinach then freeze until ready for use-and if making \
sorbet, use a small to medium sized food processor) \ 
that you plan to use that way you can avoid adding so \
much ice if at all-when making your smoothie. \
After about a year, the motor was making a funny noise. \
I called customer service but the warranty expired \
already, so I had to buy another one. FYI: The overall \
quality has gone done in these types of products, so \
they are kind of counting on brand recognition and \
consumer loyalty to maintain sales. Got it in about \
two days.
"""

reviews = [review_1, review_2, review_3, review_4]
# Out:
# <>:50: SyntaxWarning: invalid escape sequence '\ '
# <>:50: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/zt/w93lx4vj4bdbsqvppzkc5_940000gn/T/ipykernel_17281/58617423.py:50: SyntaxWarning: invalid escape sequence '\ '
#   very hard items like beans, ice, rice, etc. in the \

# %%
for i in range(len(reviews)):
    prompt = f"""
    Your task is to generate a short summary of a product \ 
    review from an ecommerce site. 

    Summarize the review below, delimited by triple \
    backticks in at most 20 words. 

    Review: ```{reviews[i]}```
    """

    response = get_completion(prompt)
    print(i, response, "\n")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\ '
# <>:11: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/zt/w93lx4vj4bdbsqvppzkc5_940000gn/T/ipykernel_17281/393577692.py:11: SyntaxWarning: invalid escape sequence '\ '
# 0 Summary:
# Cute panda plush loved by daughter, but small for price. Arrived early, enjoyable to play with.
#
# 1 Great lamp with storage, fast delivery, excellent customer service for missing parts. Company cares about customers.
#
# 2 Impressive battery life, small brush head, good deal for $50, generic replacement heads available, leaves teeth feeling clean.
#
# 3 Summary: Price increased post-sale, quality decline, motor issue after a year, frozen fruits tip for smoothies.

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
# Version 1 - Summary of all reviews considring price, shipping, delivery and customer satisfaction.

for i in range(len(reviews)):
    prompt = f"""
    Your task is to extract relevant information from \ 
a product review from an ecommerce site to give \
feedback to the Shipping department. 

From the review below, delimited by triple quotes \
extract the information relevant to price, shipping \ 
delivery and customer satisfaction. Limit to 30 words. 
 

    Review: ```{reviews[i]}```
    """

    response = get_completion(prompt)
    print(i, response, "\n")
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\ '
# <>:14: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/zt/w93lx4vj4bdbsqvppzkc5_940000gn/T/ipykernel_17281/2488949357.py:14: SyntaxWarning: invalid escape sequence '\ '
# 0 Price: Paid a bit much for the size.
# Shipping: Arrived a day earlier than expected.
# Customer Satisfaction: Daughter loves it, soft, cute, friendly look.
#
# 1 Price point not too high, fast shipping (2 days), customer satisfaction with quick replacement of broken part and missing piece. Great company that cares about customers.
#
# 2 Price: Around $50 is considered a good deal. Shipping delivery: Not mentioned. Customer satisfaction: Impressed with battery life, but wishes toothbrush head was bigger for better cleaning between teeth.
#
# 3 Price: 17 piece system was $49 on sale, increased to $70-$89 in December. 11 piece system went up $10.
# Shipping: Received in about two days.
# ...

# %%
# Version 2 - Reducing length to 20 words

for i in range(len(reviews)):
    prompt = f"""
    Your task is to extract relevant information from \ 
a product review from an ecommerce site to give \
feedback to the Shipping department. 

From the review below, delimited by triple quotes \
extract the information relevant to price, shipping \ 
delivery and customer satisfaction. Limit to 20 words. 
 

    Review: ```{reviews[i]}```
    """

    response = get_completion(prompt)
    print(i, response, "\n")
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\ '
# <>:16: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/zt/w93lx4vj4bdbsqvppzkc5_940000gn/T/ipykernel_17281/4094176783.py:16: SyntaxWarning: invalid escape sequence '\ '
# 0 Price: "a bit small for what I paid", Shipping: "arrived a day earlier than expected", Customer satisfaction: "daughter loves it".
#
# 1 Price point not too high, fast shipping in 2 days, customer satisfied with quick replacement of broken parts.
#
# 2 Price: Around $50 is considered a good deal. Shipping delivery: Not mentioned. Customer satisfaction: Teeth feel sparkly clean, battery life impressive.
#
# 3 Price: $49 on sale in November, increased to $70-$89 in December. Customer satisfaction: Motor issue after a year. Shipping: Received in about two days.

# %%
# Version 3  - focus on the perceived value

for i in range(len(reviews)):
    prompt = f"""
    Your task is to extract relevant information from \ 
a product review from an ecommerce site to give \
feedback to the Shipping department. 

From the review below, delimited by triple quotes \
extract the information relevant to price, shipping \ 
delivery and customer satisfaction. Focus on any aspects \
that are relevant to the perceived value. Limit to 20 words. 
 

    Review: ```{reviews[i]}```
    """

    response = get_completion(prompt)
    print(i, response, "\n")
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\ '
# <>:17: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/zt/w93lx4vj4bdbsqvppzkc5_940000gn/T/ipykernel_17281/3776555801.py:17: SyntaxWarning: invalid escape sequence '\ '
# 0 Price: "a bit small for what I paid", "other options that are bigger for the same price"
# Shipping: "arrived a day earlier than expected"
# Customer satisfaction: "daughter loves it", "soft and super cute", "friendly look"
#
# 1 Price point not too high, fast shipping (2 days), excellent customer service, missing part quickly resolved. Great value.
#
# 2 Price: Good deal around $50. Shipping: Not mentioned. Delivery: Not mentioned. Customer satisfaction: Teeth feel sparkly clean, battery life impressive.
#
# 3 Price: $49 on sale in November, increased to $70-$89 in December. Customer satisfaction: Motor issue after a year. Shipping: Received in about two days.

# %%
# Version 4 - Reducing length to 20 words

for i in range(len(reviews)):
    prompt = f"""
    Your task is to extract relevant information from \ 
a product review from an ecommerce site to give \
feedback to the Shipping department. 

From the review below, delimited by triple quotes \
extract the information relevant to price, shipping \ 
delivery and customer satisfaction. Focus on any aspects \
that are relevant to the perceived value. Limit to 20 words. 
 

    Review: ```{reviews[i]}```
    """

    response = get_completion(prompt)
    print(i, response, "\n")
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\ '
# <>:17: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/zt/w93lx4vj4bdbsqvppzkc5_940000gn/T/ipykernel_17281/4019678360.py:17: SyntaxWarning: invalid escape sequence '\ '
# 0 Price: "a bit small for what I paid", Shipping: "arrived a day earlier than expected", Customer satisfaction: "loves it"
#
# 1 Price point not too high, fast shipping (2 days), excellent customer service, missing part quickly resolved. Great value.
#
# 2 Price: Good deal around $50. Shipping: Not mentioned. Delivery: Not mentioned. Customer satisfaction: Impressed with battery life, feels like dentist clean.
#
# 3 Price: $49 on sale in November, increased to $70-$89 in December. Customer satisfaction: Motor issue after a year. Shipping: Received in about two days.

# %% [markdown]
# Version 1
# In Version 1 I wanted to check all reviews, considring price, shipping, delivery and customer satisfaction.
#
# Version 2
# In Version 2, I reducred the length of the reviews to 20 words to get a shorter version.
#
# Version 3
# In Vesrion 3 I took version 2 and focused on the perceived value.
#
# Which Version was successful?
# Version 2 was already a very good abbreviated version of the reviews, where as Version 3 includes hints on percieved value. Maybe a combination between Versions 2 and 3 in the next iteration might deliver a even better result. So I created Version 4 as a merger of Version 2 and Version 3 and am very satisfied with the results as their are short and up-to-the-point, but still informative.
#
# Hallucinations?
# There were no hallucinations detected.
#
# What I learned?
# Satisfying results can be achieved through some iterations. The expected results are dependend on the use case or the intented use afterwards, which should be taken into consideration. (Why and in which format do I need the results?)
#
# Conclusion
# A clear goal and an iterative approach prove to be essintial for reliable results.With this approach, the results improved in each version. I combined the clarity of Version 2 with the value focus of Version 3, which delivered a meaningful result. Through reflection on the results and through iterative refinemenet Version 4 came into being combining the advantages of the previous versions in order to produce short, consice but still meaningful and informative customer review summaries.
